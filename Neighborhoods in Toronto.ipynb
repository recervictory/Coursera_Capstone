# %%
from bs4 import BeautifulSoup #Web Scrapping
import pandas as pd #library for dataframe
import numpy as np
from tabulate import tabulate
import json #library for json file
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # map rendering library

# %%
# Import Toranto Neighbourhood wiki html file
import requests
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
response = requests.get(url)
response.text[:100]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title'

# %%
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))[0]
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
print('Number of Borough Not assigned : {}'.format(df[df['Borough'] == 'Not assigned'].count()))
# Out:
# Number of Borough Not assigned : Postcode         77
# Borough          77
# Neighbourhood    77
# dtype: int64

# %%
# Ignore cells with a borough that is Not assigned.
df = df[df['Borough'] != 'Not assigned']
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor

# %%
tornto = df.groupby(['Postcode','Borough']).agg(lambda x: ','.join(set(x)))
tornto = tornto.reset_index()
tornto.columns = ['Postal Code','Borough','Neighborhood']
tornto.head(10)
# Out:
#   Postal Code      Borough                                   Neighborhood
# 0         M1B  Scarborough                                  Rouge,Malvern
# 1         M1C  Scarborough           Rouge Hill,Port Union,Highland Creek
# 2         M1E  Scarborough                West Hill,Guildwood,Morningside
# 3         M1G  Scarborough                                         Woburn
# 4         M1H  Scarborough                                      Cedarbrae
# 5         M1J  Scarborough                            Scarborough Village
# 6         M1K  Scarborough      East Birchmount Park,Ionview,Kennedy Park
# 7         M1L  Scarborough                  Clairlea,Oakridge,Golden Mile
# 8         M1M  Scarborough  Scarborough Village West,Cliffcrest,Cliffside
# 9         M1N  Scarborough                     Birch Cliff,Cliffside West

# %%
# Read GeoFile
geo_data = pd.read_csv('https://cocl.us/Geospatial_data')
geo_data.head()
#geo_data.to_csv(r'Data\geodata.csv')
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
tornto = pd.merge(tornto,geo_data,how='left',on='Postal Code')
tornto.head()
# Out:
#   Postal Code      Borough                          Neighborhood   Latitude  \
# 0         M1B  Scarborough                         Rouge,Malvern  43.806686
# 1         M1C  Scarborough  Rouge Hill,Port Union,Highland Creek  43.784535
# 2         M1E  Scarborough       West Hill,Guildwood,Morningside  43.763573
# 3         M1G  Scarborough                                Woburn  43.770992
# 4         M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# # Use geopy library to get the latitude and longitude values of Toronto City.

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.653963, -79.387207.

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(tornto['Latitude'], tornto['Longitude'],tornto['Borough'], tornto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Import _Foursquare_ Credential

# %%
CLIENT_ID = 'UBLX5C1RQM4EQJIT20SYTFY2YAMDC51IIGFTHGEHKXR2T44B' # Foursquare ID
CLIENT_SECRET = 'EQ5U14PRWPDADRFB5KEJY3CG4VBDABSWKWZQHTHSU5YPHTWO' #Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: UBLX5C1RQM4EQJIT20SYTFY2YAMDC51IIGFTHGEHKXR2T44B
# CLIENT_SECRET:EQ5U14PRWPDADRFB5KEJY3CG4VBDABSWKWZQHTHSU5YPHTWO

# %% [markdown]
# # Foursquare
# ### Function that extracts the category of the venue

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


#Extract Venues from FourSquare as lat and long given as input
def foursquareVenue(neighborhood_name, neighborhood_latitude, neighborhood_longitude,redius=500,limit=100):
    
    """Extract Venues from FourSquare as lat and long given as input"""
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
     CLIENT_ID, CLIENT_SECRET, VERSION, neighborhood_latitude, neighborhood_longitude, radius, LIMIT)
    
    print("Neighborhood Name: {}".format(neighborhood_name))

    #Get Url resopnse from FourSquare
    from pandas.io.json import json_normalize

    response = json_normalize(requests.get(url).json()["response"]['groups'][0]['items']) #Save as json file as normalized datafarme
    # clean columns
    columns_name = ['vanue','vanue_category','venue_latitude','venue_longitude']
    if response.empty:
        venues = pd.DataFrame(np.nan,index=[0],columns= columns_name)
    else:
    # filter columns
        venues = response.loc[:, ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']]

        # filter the category for each row
        # use function get_category_type() apply row wise in category object
        venues['venue.categories'] = venues.apply(get_category_type, axis=1)
        # clean columns
        venues.columns = columns_name
    #Add Neighborhood Details
    venues['neighborhood_name'], venues['neighborhood_latitude'], venues['neighborhood_longitude'] = neighborhood_name, neighborhood_latitude, neighborhood_longitude

    return venues

# %%
neighborhood_latitude = tornto.loc[16, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = tornto.loc[16, 'Longitude'] # neighborhood longitude value

neighborhood_name = tornto.loc[1, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of **{}** are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of **Rouge Hill,Port Union,Highland Creek** are 43.836124700000006, -79.20563609999999.

# %%
def foursquare(neighborhood_name, neighborhood_latitude, neighborhood_longitude,redius=500,limit=100):
    
    """Extract Venues from FourSquare as lat and long given as input"""
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
     CLIENT_ID, CLIENT_SECRET, VERSION, neighborhood_latitude, neighborhood_longitude, radius, LIMIT)
    response = json_normalize(requests.get(url).json()["response"]['groups'][0]['items'])
    return response
foursquare('Upper Rouge',  43.836125, -79.205636)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
A = foursquareVenue('Upper Rouge',  43.836125, -79.205636)
B = foursquareVenue(neighborhood_name, neighborhood_latitude, neighborhood_longitude)
pd.concat([A,B],axis=0)
# Out:
# Neighborhood Name: Upper Rouge
# Neighborhood Name: Northwest
#                     vanue       vanue_category  venue_latitude  \
# 0                     NaN                  NaN             NaN
# 0      Economy Rent A Car  Rental Car Location       43.708471
# 1  Logistics Distribution                  Bar       43.707554
# 2           Saand Rexdale            Drugstore       43.705072
#
#    venue_longitude neighborhood_name  neighborhood_latitude  \
# 0              NaN       Upper Rouge              43.836125
# 0       -79.589943         Northwest              43.706748
# 1       -79.589252         Northwest              43.706748
# 2       -79.598725         Northwest              43.706748
#
#    neighborhood_longitude
# 0              -79.205636
# 0              -79.594054
# 1              -79.594054
# 2              -79.594054

# %%
column_names = foursquareVenue(neighborhood_name,  neighborhood_latitude, neighborhood_longitude).columns
df = pd.DataFrame(columns = column_names)
# Out:
# Neighborhood Name: Northwest

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [vanue, vanue_category, venue_latitude, venue_longitude, neighborhood_name, neighborhood_latitude, neighborhood_longitude]
# Index: []

# %%
for neighborhood_name, neighborhood_latitude, neighborhood_longitude in zip(tornto['Neighborhood'],tornto['Latitude'],tornto['Longitude']):
    x = foursquareVenue(neighborhood_name,  neighborhood_latitude, neighborhood_longitude)
    df = pd.concat([df,x],axis=0)
# Out:
# Neighborhood Name: Rouge,Malvern
# Neighborhood Name: Rouge Hill,Port Union,Highland Creek
# Neighborhood Name: West Hill,Guildwood,Morningside
# Neighborhood Name: Woburn
# Neighborhood Name: Cedarbrae
# Neighborhood Name: Scarborough Village
# Neighborhood Name: East Birchmount Park,Ionview,Kennedy Park
# Neighborhood Name: Clairlea,Oakridge,Golden Mile
# Neighborhood Name: Scarborough Village West,Cliffcrest,Cliffside
# Neighborhood Name: Birch Cliff,Cliffside West
# Neighborhood Name: Wexford Heights,Dorset Park,Scarborough Town Centre
# Neighborhood Name: Maryvale,Wexford
# Neighborhood Name: Agincourt
# Neighborhood Name: Tam O'Shanter,Sullivan,Clarks Corners
# Neighborhood Name: Steeles East,Milliken,L'Amoreaux East,Agincourt North
# Neighborhood Name: L'Amoreaux West
# Neighborhood Name: Upper Rouge
# Neighborhood Name: Hillcrest Village
# Neighborhood Name: Henry Farm,Fairview,Oriole
# Neighborhood Name: Bayview Village
# Neighborhood Name: Silver Hills,York Mills
# Neighborhood Name: Willowdale,Newtonbrook
# Neighborhood Name: Willowdale South
# Neighborhood Name: York Mills West
# Neighborhood Name: Willowdale West
# Neighborhood Name: Parkwoods
# Neighborhood Name: Don Mills North
# Neighborhood Name: Don Mills South,Flemingdon Park
# Neighborhood Name: Wilson Heights,Downsview North,Bathurst Manor
# Neighborhood Name: Northwood Park,York University
# Neighborhood Name: Downsview East,CFB Toronto
# Neighborhood Name: Downsview West
# Neighborhood Name: Downsview Central
# Neighborhood Name: Downsview Northwest
# Neighborhood Name: Victoria Village
# Neighborhood Name: Parkview Hill,Woodbine Gardens
# Neighborhood Name: Woodbine Heights
# Neighborhood Name: The Beaches
# Neighborhood Name: Leaside
# Neighborhood Name: Thorncliffe Park
# Neighborhood Name: East Toronto
# Neighborhood Name: The Danforth West,Riverdale
# Neighborhood Name: The Beaches West,India Bazaar
# Neighborhood Name: Studio District
# Neighborhood Name: Lawrence Park
# Neighborhood Name: Davisville North
# Neighborhood Name: North Toronto West
# Neighborhood Name: Davisville
# Neighborhood Name: Moore Park,Summerhill East
# Neighborhood Name: Deer Park,South Hill,Summerhill West,Forest Hill SE,Rathnelly
# Neighborhood Name: Rosedale
# Neighborhood Name: Cabbagetown,St. James Town
# Neighborhood Name: Church and Wellesley
# Neighborhood Name: Harbourfront
# Neighborhood Name: Garden District,Ryerson
# Neighborhood Name: St. James Town
# Neighborhood Name: Berczy Park
# Neighborhood Name: Central Bay Street
# Neighborhood Name: Adelaide,Richmond,King
# Neighborhood Name: Harbourfront East,Toronto Islands,Union Station
# Neighborhood Name: Design Exchange,Toronto Dominion Centre
# Neighborhood Name: Commerce Court,Victoria Hotel
# Neighborhood Name: Bedford Park,Lawrence Manor East
# Neighborhood Name: Roselawn
# Neighborhood Name: Forest Hill North,Forest Hill West
# Neighborhood Name: The Annex,Yorkville,North Midtown
# Neighborhood Name: University of Toronto,Harbord
# Neighborhood Name: Kensington Market,Chinatown,Grange Park
# Neighborhood Name: King and Spadina,Bathurst Quay,Island airport,South Niagara,CN Tower,Harbourfront West,Railway Lands
# Neighborhood Name: Stn A PO Boxes 25 The Esplanade
# Neighborhood Name: Underground city,First Canadian Place
# Neighborhood Name: Lawrence Manor,Lawrence Heights
# Neighborhood Name: Glencairn
# Neighborhood Name: Humewood-Cedarvale
# Neighborhood Name: Caledonia-Fairbanks
# Neighborhood Name: Christie
# Neighborhood Name: Dufferin,Dovercourt Village
# Neighborhood Name: Little Portugal,Trinity
# Neighborhood Name: Parkdale Village,Brockton,Exhibition Place
# Neighborhood Name: Downsview,North Park,Upwood Park
# Neighborhood Name: Silverthorn,Keelesdale,Del Ray,Mount Dennis
# Neighborhood Name: Runnymede,The Junction North
# Neighborhood Name: The Junction South,High Park
# Neighborhood Name: Parkdale,Roncesvalles
# Neighborhood Name: Swansea,Runnymede
# Neighborhood Name: Queen's Park
# Neighborhood Name: Canada Post Gateway Processing Centre
# Neighborhood Name: Business Reply Mail Processing Centre 969 Eastern
# Neighborhood Name: Mimico South,Humber Bay Shores,New Toronto
# Neighborhood Name: Long Branch,Alderwood
# Neighborhood Name: The Kingsway,Montgomery Road,Old Mill North
# Neighborhood Name: Mimico NE,Kingsway Park South East,The Queensway East,Old Mill South,Humber Bay,Royal York South East,King's Mill Park,Sunnylea
# Neighborhood Name: Kingsway Park South West,The Queensway West,Royal York South West,Mimico NW,South of Bloor
# Neighborhood Name: Islington Avenue
# Neighborhood Name: Martin Grove,Princess Gardens,West Deane Park,Islington,Cloverdale
# Neighborhood Name: Markland Wood,Old Burnhamthorpe,Eringate,Bloordale Gardens
# Neighborhood Name: Humber Summit
# Neighborhood Name: Emery,Humberlea
# Neighborhood Name: Weston
# Neighborhood Name: Westmount
# Neighborhood Name: Richview Gardens,St. Phillips,Kingsview Village,Martin Grove Gardens
# Neighborhood Name: Mount Olive,Thistletown,Jamestown,Silverstone,Humbergate,South Steeles,Beaumond Heights,Albion Gardens
# Neighborhood Name: Northwest

# %%
df.head()
# Out:
#                    vanue        vanue_category  venue_latitude  \
# 0                Wendy's  Fast Food Restaurant       43.807448
# 1  Interprovincial Group            Print Shop       43.805630
# 0  Royal Canadian Legion                   Bar       43.782533
# 0      G & G Electronics     Electronics Store       43.765309
# 1             Marina Spa                   Spa       43.766000
#
#    venue_longitude                     neighborhood_name  \
# 0       -79.199056                         Rouge,Malvern
# 1       -79.200378                         Rouge,Malvern
# 0       -79.163085  Rouge Hill,Port Union,Highland Creek
# 0       -79.191537       West Hill,Guildwood,Morningside
# 1       -79.191000       West Hill,Guildwood,Morningside
#
#    neighborhood_latitude  neighborhood_longitude
# 0              43.806686              -79.194353
# 1              43.806686              -79.194353
# 0              43.784535              -79.160497
# 0              43.763573              -79.188711
# 1              43.763573              -79.188711
